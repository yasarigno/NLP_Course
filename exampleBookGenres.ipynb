# %% [markdown]
# <a href="https://colab.research.google.com/github/yasarigno/NLP_DeepLearning_Course/blob/main/exampleBookGenres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/Shared Datasets/Book genres/data.csv")
data
# Out:
#       index                              title    genre  \
# 0         0                  Drowned Wednesday  fantasy
# 1         1                      The Lost Hero  fantasy
# 2         2          The Eyes of the Overworld  fantasy
# 3         3                    Magic's Promise  fantasy
# 4         4                     Taran Wanderer  fantasy
# ...     ...                                ...      ...
# 4652   4652                            Hounded  fantasy
# 4653   4653  Charlie and the Chocolate Factory  fantasy
# 4654   4654                         Red Rising  fantasy
# 4655   4655                          Frostbite  fantasy
# 4656   4656                           Radiance  fantasy
#
#                                                 summary
# 0      Drowned Wednesday is the first Trustee among ...
# 1      As the book opens, Jason awakens on a school ...
# 2      Cugel is easily persuaded by the merchant Fia...
# 3      The book opens with Herald-Mage Vanyel return...
# ...

# %%
data.describe(include="all")
# Out:
#               index      title     genre  \
# count   4657.000000       4657      4657
# unique          NaN       4296        10
# top             NaN  Bloodline  thriller
# freq            NaN          4      1023
# mean    2328.000000        NaN       NaN
# std     1344.504432        NaN       NaN
# min        0.000000        NaN       NaN
# 25%     1164.000000        NaN       NaN
# 50%     2328.000000        NaN       NaN
# 75%     3492.000000        NaN       NaN
# max     4656.000000        NaN       NaN
#
#                                                   summary
# count                                                4657
# unique                                               4542
# top     The incredible true story of the women who fou...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# ...

# %% [markdown]
# variable
#
# categorical variable
# numerical variable
# - continuous variable
# - discrete variable

# %%
data["genre"].value_counts()
# Out:
# thriller      1023
# fantasy        876
# science        647
# history        600
# horror         600
# crime          500
# romance        111
# psychology     100
# sports         100
# travel         100
# Name: genre, dtype: int64

# %%
fig = plt.figure(figsize=(10, 6))
plt.xticks(rotation=40)
bp = sns.barplot(
    x=data["genre"].value_counts().index,
    y=data["genre"].value_counts(),
    data=data,
    saturation=0.9,
    # order=order,
    # color='darkred',
    ci=None)

# %%
histogram - continuos variable 

barplot - discrete variable
